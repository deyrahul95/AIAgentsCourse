# %% [markdown]
# ### OpenAI Agent SDK

# %%
from dotenv import load_dotenv
from agents import Agent, Runner
from agents.extensions.models.litellm_model import LitellmModel
import os

# %%
load_dotenv(override=True)
# Out:
# True

# %%
model = LitellmModel(
    model="openai/gpt-oss-120b:free",
    base_url=os.getenv("OPENROUTER_API_URL"),
    api_key=os.getenv("OPENROUTER_API_KEY"),
)

# instructions: it actually the system prompt for the agent
agent = Agent(
    name="Jokester",
    instructions="You are a joke teller",
    model=model,
)

# %%
result = await Runner.run(agent, "Tell me a joke about Autonomous AI Agents")
print(result.final_output)
# Out:
# OPENAI_API_KEY is not set, skipping trace export
# Why did the autonomous AI agent quit its job?
#
# Because every time it tried to take a break, it kept “self‑optimizing” the coffee machine into a quantum espresso! ☕🤖
# OPENAI_API_KEY is not set, skipping trace export
